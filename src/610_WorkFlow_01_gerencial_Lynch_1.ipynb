# %% [markdown]
# <a href="https://colab.research.google.com/github/claralynch/labo2025v/blob/main/src/610_WorkFlow_01_gerencial_Lynch_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
# %%shell
#
# mkdir -p "/content/.drive/My Drive/labo1"
# mkdir -p "/content/buckets"
# ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1
#
# mkdir -p ~/.kaggle
# cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
# chmod 600 ~/.kaggle/kaggle.json
#
#
# mkdir -p /content/buckets/b1/exp
# mkdir -p /content/buckets/b1/datasets
# mkdir -p /content/datasets
#
#
# webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
# destino_local="/content/datasets"
# destino_bucket="/content/buckets/b1/datasets"
#
#
# archivo="dataset_pequeno.csv"
#
# if ! test -f $destino_bucket/$archivo; then
#   wget  $webfiles/$archivo  -O $destino_bucket/$archivo
# fi
#
#
# if ! test -f $destino_local/$archivo; then
#   cp  $destino_bucket/$archivo  $destino_local/$archivo
# fi
#
# #-------
#
# archivo="gerencial_competencia_2025.csv.gz"
#
# if ! test -f $destino_bucket/$archivo; then
#   wget  $webfiles/$archivo  -O $destino_bucket/$archivo
# fi
#
#
# if ! test -f $destino_local/$archivo; then
#   cp  $destino_bucket/$archivo  $destino_local/$archivo
# fi
#
# #-------
#
# archivo="Indice-FACPCE.xlsx"
#
# if ! test -f $destino_bucket/$archivo; then
#   wget  $webfiles/$archivo  -O $destino_bucket/$archivo
# fi
#
#
# if ! test -f $destino_local/$archivo; then
#   cp  $destino_bucket/$archivo  $destino_local/$archivo
# fi
# Out:
# --2025-11-30 19:28:10--  https://storage.googleapis.com/open-courses/austral2025-af91//Indice-FACPCE.xlsx
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.132.207, 74.125.201.207, 74.125.202.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.132.207|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-11-30 19:28:10 ERROR 404: Not Found.

# %%
#system("ls -l /content/datasets/Indice-FACPCE.xlsx")

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 30 07:28:29 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660355 35.3 1454497    77.7 1454497  77.7
# Vcells 1226516  9.4 8388608    64.0 1975136  15.1

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 334561

PARAM$experimento <- 100
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %%
#colnames(dataset)

# %%
#dim(dataset)

# %%
head(dataset)
# Out:
#   numero_de_cliente foto_mes internet cliente_edad cliente_antiguedad
# 1 29186441          202005   1        61           282
# 2 29187961          202005   1        61           312
# 3 29193101          202005   1        67           365
# 4 29193281          202005   1        54           158
# 5 29198891          202005   1        54           312
# 6 29205441          202005   1        72             6
#   mrentabilidad mrentabilidad_annual mcomisiones mactivos_margen
# 1 2354.94       43761.59             1682.14      -139.02
# 2 5066.31       47268.33             3875.62     -3536.03
# 3 4809.42       37996.66             6982.73     -2962.24
# 4 2979.52       88436.59             3350.01      -908.55
# 5 3008.70       22567.32              273.68      -643.87
# 6  394.19        1607.93              159.49        -9.92
#   mpasivos_margen ⋯ ccallcenter_transacciones chomebanking_transacciones
# 1  712.60         ⋯ 0                          20
# 2 4551.11         ⋯ 0                         228
# 3 1109.46         ⋯ 0                         133
# 4  592.70         ⋯ 2                          10
# 5 2975.52         ⋯ 0                         124
# 6  210.01         ⋯ 0                          41
#   ctrx_quarter Master_status Master_fechaalta Master_mpagominimo Visa_status
# 1  47          0             6507                0.00            0
# 2 232          0             5939             2017.56            0
# 3 149          0             2026             2838.66            0
# 4 115          0             3125              844.56            0
# 5  32          0             7202              234.60            0
# 6  32          0              157                0.00            0
#   Visa_fechaalta Visa_mpagominimo clase_ternaria
# 1 7671           1043.97          CONTINUA
# 2 8090           7495.47          CONTINUA
# 3 2026           1653.93          CONTINUA
# 4 3350           2029.29          CONTINUA
# 5 7242           1395.87          CONTINUA
# 6  157             58.65          CONTINUA

# %%
#conteo_ceros_todas_columnas <- sapply(dataset, function(x) sum(x == 0))
#print(conteo_ceros_todas_columnas)

# %%
#filas_de_ceros <- apply(dataset, 1, function(x) all(x == 0))
#print(sum(filas_de_ceros))

# %%
#filas <- dataset[dataset$foto_mes == 202006, ]

# Imprimir el resultado
#print(filas)

# %%
#cantidad_ceros <- sum(dataset$mpayroll == 0)
#print(cantidad_ceros)

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA a los valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
'''
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
'''
# Out:
# Error in parse(text = input): <text>:1:3: unexpected string constant
# 13: dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
# 14: '
#       ^
# Traceback:

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerencia pero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
install.packages("readxl")
install.packages("dplyr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#PASO 1
library(readxl)
library(data.table)
library(dplyr)
fapce <- read_excel(
  "/content/datasets/Indice-FACPCE.xlsx") %>%
  rename_with(~ c("foto_mes", "IPC", "coeficiente_de_ajuste")) %>%
  mutate(
    foto_mes = format(as.Date(foto_mes), "%Y%m"),
    IPC = as.numeric(IPC),
    coeficiente_de_ajuste = as.numeric(coeficiente_de_ajuste)
  ) %>%
  as.data.table()
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# Error in utils::unzip(zip_path, list = TRUE): zip file '/content/datasets/Indice-FACPCE.xlsx' cannot be opened
# Traceback:
#
# 1. as.data.table(.)
# 2. mutate(., foto_mes = format(as.Date(foto_mes), "%Y%m"), IPC = as.numeric(IPC),
#  .     coeficiente_de_ajuste = as.numeric(coeficiente_de_ajuste))
# 3. rename_with(., ~c("foto_mes", "IPC", "coeficiente_de_ajuste"))
# 4. read_excel("/content/datasets/Indice-FACPCE.xlsx")
# 5. read_excel_(path = path, sheet = sheet, range = range, col_names = col_names,
#  .     col_types = col_types, na = na, trim_ws = trim_ws, skip = skip,
#  .     n_max = n_max, guess_max = guess_max, progress = progress,
#  .     .name_repair = .name_repair, format = format)
# 6. set_readxl_names(read_fun(path = path, sheet_i = sheet, limits = limits,
#  .     shim = shim, col_names = col_names, col_types = col_types,
#  .     na = na, trim_ws = trim_ws, guess_max = guess_max, progress = progress),
#  .     .name_repair = .name_repair)
# 7. tibble::as_tibble(l, .name_repair = .name_repair)
# 8. read_fun(path = path, sheet_i = sheet, limits = limits, shim = shim,
#  .     col_names = col_names, col_types = col_types, na = na, trim_ws = trim_ws,
#  .     guess_max = guess_max, progress = progress)
# 9. (function (zip_path, file_path)
#  . {
#  .     files <- utils::unzip(zip_path, list = TRUE)
#  .     indx <- match(file_path, files$Name)
#  .     if (is.na(indx)) {
#  .         stop("Couldn't find '", file_path, "' in '", zip_path,
#  .             "'", call. = FALSE)
#  .     }
#  .     size <- files$Length[indx]
#  .     con <- unz(zip_path, file_path, open = "rb")
#  .     on.exit(close(con), add = TRUE)
#  .     readBin(con, raw(), n = size)
#  . })("/content/datasets/Indice-FACPCE.xlsx", "_rels/.rels")
# 10. utils::unzip(zip_path, list = TRUE)
# 11. .handleSimpleError(function (cnd)
#   . {
#   .     watcher$capture_plot_and_output()
#   .     cnd <- sanitize_call(cnd)
#   .     watcher$push(cnd)
#   .     switch(on_error, continue = invokeRestart("eval_continue"),
#   .         stop = invokeRestart("eval_stop"), error = NULL)
#   . }, "zip file '/content/datasets/Indice-FACPCE.xlsx' cannot be opened",
#   .     base::quote(utils::unzip(zip_path, list = TRUE)))

# %%
#head(fapce)

# %%
#PASO 2
dataset <- as.data.table(dataset)

# asegurar foto_mes como texto tipo "202005"
dataset[, foto_mes := as.character(foto_mes)]
dataset[, foto_mes := gsub("[^0-9]", "", foto_mes)]
dataset[, foto_mes := substr(foto_mes, 1, 6)]

# %%
#PASO 3
cols_borrar <- c("coeficiente_de_ajuste", "coeficiente_de_ajuste.x", "coeficiente_de_ajuste.y")

for (col in cols_borrar) {
  if (col %in% names(dataset)) dataset[, (col) := NULL]
}

# %%
#PASO 4
dataset <- merge(
  dataset,
  fapce[, .(foto_mes, coeficiente_de_ajuste)],
  by = "foto_mes",
  all.x = TRUE
)
# Out:
# Error: object 'fapce' not found
# Traceback:
#
# 1. merge.data.table(dataset, fapce[, .(foto_mes, coeficiente_de_ajuste)],
#  .     by = "foto_mes", all.x = TRUE)
# 2. is.data.table(y)
# 3. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'fapce' not found", base::quote(eval(expr, envir)))

# %%
#PASO 5 MERGE POR FOTO_MES
vars_ajustar <- c(
  "mrentabilidad",
  "mrentabilidad_annual",
  "mcomisiones",
  "mactivos_margen",
  "mpasivos_margen",
  "mcuenta_corriente",
  "mcaja_ahorro",
  "mcuentas_saldo",
  "mtarjeta_visa_consumo",
  "mtarjeta_master_consumo",
  "mprestamos_personales",
  "mpayroll",
  "Master_mpagominimo",
  "Visa_mpagominimo"
)

dataset[, (vars_ajustar) := lapply(.SD, as.numeric), .SDcols = vars_ajustar]

# %%
#PASO 6
dataset[
  ,
  (vars_ajustar) := lapply(.SD, function(x) x * coeficiente_de_ajuste),
  .SDcols = vars_ajustar
]
# Out:
# Error in FUN(X[[i]], ...): object 'coeficiente_de_ajuste' not found
# Traceback:
#
# 1. `[.data.table`(dataset, , `:=`((vars_ajustar), lapply(.SD, function(x) x *
#  .     coeficiente_de_ajuste)), .SDcols = vars_ajustar)
# 2. eval(jsub, SDenv, parent.frame())
# 3. eval(jsub, SDenv, parent.frame())
# 4. lapply(.SD, function(x) x * coeficiente_de_ajuste)
# 5. FUN(X[[i]], ...)
# 6. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'coeficiente_de_ajuste' not found", base::quote(FUN(X[[i]],
#  .     ...)))

# %%
#Paso #7 cambio el tipo de valor de foto_mes, lo vuelvo a int.
dataset[, foto_mes := as.integer(foto_mes)]

# %%
head(dataset)
# Out:
#   numero_de_cliente foto_mes internet cliente_edad cliente_antiguedad
# 1 29186441          202005   1        61           282
# 2 29187961          202005   1        61           312
# 3 29193101          202005   1        67           365
# 4 29193281          202005   1        54           158
# 5 29198891          202005   1        54           312
# 6 29205441          202005   1        72             6
#   mrentabilidad mrentabilidad_annual mcomisiones mactivos_margen
# 1 2354.94       43761.59             1682.14      -139.02
# 2 5066.31       47268.33             3875.62     -3536.03
# 3 4809.42       37996.66             6982.73     -2962.24
# 4 2979.52       88436.59             3350.01      -908.55
# 5 3008.70       22567.32              273.68      -643.87
# 6  394.19        1607.93              159.49        -9.92
#   mpasivos_margen ⋯ ccallcenter_transacciones chomebanking_transacciones
# 1  712.60         ⋯ 0                          20
# 2 4551.11         ⋯ 0                         228
# 3 1109.46         ⋯ 0                         133
# 4  592.70         ⋯ 2                          10
# 5 2975.52         ⋯ 0                         124
# 6  210.01         ⋯ 0                          41
#   ctrx_quarter Master_status Master_fechaalta Master_mpagominimo Visa_status
# 1  47          0             6507                0.00            0
# 2 232          0             5939             2017.56            0
# 3 149          0             2026             2838.66            0
# 4 115          0             3125              844.56            0
# 5  32          0             7202              234.60            0
# 6  32          0              157                0.00            0
#   Visa_fechaalta Visa_mpagominimo clase_ternaria
# 1 7671           1043.97          CONTINUA
# 2 8090           7495.47          CONTINUA
# 3 2026           1653.93          CONTINUA
# 4 3350           2029.29          CONTINUA
# 5 7242           1395.87          CONTINUA
# 6  157             58.65          CONTINUA

# %%
# sin codigo en esta primera version del workflow para gentencial, lo anterior fue agregado al código original.

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %% [markdown]
# ###CUIDADO QUE EL DRIFTING cambió a foto_mes a un CHARACTER, hay que castearla a entero con as.integer()

# %%
#dataset$foto_mes <- as.integer(dataset$foto_mes)

# %%
#head(dataset)

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa y la cantidad de variables (columnas)
dim(dataset)
colnames(dataset)
# Out:
# [1] 273666     34
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %%
### SON 20 VARIABLES FINANCIERAS ###

generar_variables_financieras_intra_mes <- function(df_finanzas) {
  df_finanzas <- as.data.table(df_finanzas)

  safe_divide <- function(num, denom) {
    result <- ifelse(denom == 0, 0, num / denom)
    return(result)
  }

  df_finanzas$ratio_saldo_ingreso <- safe_divide(df_finanzas$mcuentas_saldo, df_finanzas$mrentabilidad)
  df_finanzas$promedio_diario_consumos <- (df_finanzas$mtarjeta_visa_consumo + df_finanzas$mtarjeta_master_consumo) / 30
  df_finanzas$dias_consumo_alto <- as.integer((df_finanzas$mtarjeta_visa_consumo + df_finanzas$mtarjeta_master_consumo) > 175000) * 30 #mayor a USD1000 al tipo de cambio blue de ese mes"
  df_finanzas$ratio_comisiones_consumos <- safe_divide(df_finanzas$mcomisiones, (df_finanzas$mtarjeta_visa_consumo + df_finanzas$mtarjeta_master_consumo))
  df_finanzas$ingreso_ajustado_antiguedad <- safe_divide(df_finanzas$mrentabilidad, df_finanzas$cliente_antiguedad)
  df_finanzas$saldo_cercano_cero <- as.integer(df_finanzas$mcuentas_saldo < 175) #menor que USD1 al tipo de cambio dolarblue de ese mes#
  df_finanzas$porc_consumo_digital <- safe_divide((df_finanzas$mtarjeta_visa_consumo + df_finanzas$mtarjeta_master_consumo), df_finanzas$mrentabilidad)
  df_finanzas$total_movimientos <- df_finanzas$mtarjeta_visa_consumo + df_finanzas$mtarjeta_master_consumo + df_finanzas$chomebanking_transacciones
  df_finanzas$ratio_productos_consumos <- safe_divide(df_finanzas$cproductos, (df_finanzas$mtarjeta_visa_consumo + df_finanzas$mtarjeta_master_consumo))
  df_finanzas$promedio_comisiones <- df_finanzas$mcomisiones / 30
  df_finanzas$saldo_alto <- as.integer(df_finanzas$mcuentas_saldo > 1000000)
  df_finanzas$dias_sin_transacciones <- 30 - (df_finanzas$ctarjeta_visa_transacciones + df_finanzas$chomebanking_transacciones)
  df_finanzas$ingreso_mensual_promedio <- safe_divide(df_finanzas$mrentabilidad_annual, df_finanzas$cliente_antiguedad)
  df_finanzas$promedio_diario_comisiones <- df_finanzas$mcomisiones / 30
  df_finanzas$proporcion_consumos_ingresos <- safe_divide((df_finanzas$mtarjeta_visa_consumo + df_finanzas$mtarjeta_master_consumo), df_finanzas$mrentabilidad)
  df_finanzas$ratio_comisiones_saldo <- safe_divide(df_finanzas$mcomisiones, df_finanzas$mcuentas_saldo)
  df_finanzas$proporcion_transacciones_tarjeta <- safe_divide(df_finanzas$ctarjeta_visa_transacciones, (df_finanzas$ctarjeta_visa_transacciones + df_finanzas$chomebanking_transacciones))
  df_finanzas$productos_por_antiguedad <- safe_divide(df_finanzas$cproductos, df_finanzas$cliente_antiguedad)
  df_finanzas$promedio_diario_consumos_total <- (df_finanzas$mtarjeta_visa_consumo + df_finanzas$mtarjeta_master_consumo + df_finanzas$mrentabilidad) / 30
  df_finanzas$gastos_semanales <- (df_finanzas$mtarjeta_visa_consumo + df_finanzas$mtarjeta_master_consumo) / 4
  return(df_finanzas)
}

# Para aplicar a un dataset llamado dataset:
dataset <- generar_variables_financieras_intra_mes(dataset)

# %%
head(dataset)
# Out:
#   numero_de_cliente foto_mes internet cliente_edad cliente_antiguedad
# 1 29186441          202005   1        61           282
# 2 29187961          202005   1        61           312
# 3 29193101          202005   1        67           365
# 4 29193281          202005   1        54           158
# 5 29198891          202005   1        54           312
# 6 29205441          202005   1        72             6
#   mrentabilidad mrentabilidad_annual mcomisiones mactivos_margen
# 1 2354.94       43761.59             1682.14      -139.02
# 2 5066.31       47268.33             3875.62     -3536.03
# 3 4809.42       37996.66             6982.73     -2962.24
# 4 2979.52       88436.59             3350.01      -908.55
# 5 3008.70       22567.32              273.68      -643.87
# 6  394.19        1607.93              159.49        -9.92
#   mpasivos_margen ⋯ saldo_alto dias_sin_transacciones ingreso_mensual_promedio
# 1  712.60         ⋯ 0             2                   155.18294
# 2 4551.11         ⋯ 0          -233                   151.50106
# 3 1109.46         ⋯ 0          -114                   104.10044
# 4  592.70         ⋯ 0             9                   559.72525
# 5 2975.52         ⋯ 0          -100                    72.33115
# 6  210.01         ⋯ 0           -12                   267.98833
#   promedio_diario_comisiones proporcion_consumos_ingresos
# 1  56.071333                  7.336701
# 2 129.187333                 21.926254
# 3 232.757667                 21.361655
# 4 111.667000                 15.367717
# 5   9.122667                  6.468953
# 6   5.316333                  2.975722
#   ratio_comisiones_saldo proporcion_transacciones_tarjeta
# 1 0.027965404            0.28571429
# 2 0.009053206            0.13307985
# 3 0.045859263            0.07638889
# 4 0.014517676            0.52380952
# 5 0.001244525            0.04615385
# 6 0.003814963            0.02380952
#   productos_por_antiguedad promedio_diario_consumos_total gastos_semanales
# 1 0.02482270                654.41433                      4319.373
# 2 0.02243590               3871.71700                     27771.300
# 3 0.02465753               3584.88633                     25684.292
# 4 0.05696203               1625.59800                     11447.105
# 5 0.02243590                749.06133                      4865.785
# 6 1.16666667                 52.23967                       293.250

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages("lightgbm"):
# “installation of package ‘lightgbm’ had non-zero exit status”
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”

# %%
#system("apt-get install -y libboost-dev libboost-system-dev libboost-filesystem-dev") ### VER SI ES NECESARIO ###

# %%
#install.packages("devtools")  ### VER SI ES NECESARIO ###

# %%
#install.packages("lightgbm")
#library(lightgbm)

#exists("lgb.Dataset")

### VER SI ES NECESARIO ###

# %%
AgregaVarRandomForest <- function() {

  cat( "inicio AgregaVarRandomForest()\n")
  gc(verbose= FALSE)
  dataset[, clase01 := 0L ]
  dataset[ clase_ternaria %in% PARAM$FE_rf$train$clase01_valor1,
      clase01 := 1L ]

  campos_buenos <- setdiff(
    colnames(dataset),
    c( "clase_ternaria", "clase01")
  )

  dataset[, entrenamiento :=
    as.integer( foto_mes %in% PARAM$FE_rf$train$training )]

  dtrain <- lgb.Dataset(
    data = data.matrix(dataset[entrenamiento == TRUE, campos_buenos, with = FALSE]),
    label = dataset[entrenamiento == TRUE, clase01],
    free_raw_data = FALSE
  )

  modelo <- lgb.train(
     data = dtrain,
     param = PARAM$FE_rf$lgb_param,
     verbose = -100
  )

  cat( "Fin construccion RandomForest\n" )
  # grabo el modelo, achivo .model
  lgb.save(modelo, file="modelo.model" )

  qarbolitos <- copy(PARAM$FE_rf$lgb_param$num_iterations)

  periodos <- dataset[ , unique( foto_mes ) ]

  for( periodo in  periodos )
  {
    cat( "periodo = ", periodo, "\n" )
    datamatrix <- data.matrix(dataset[ foto_mes== periodo, campos_buenos, with = FALSE])

    cat( "Inicio prediccion\n" )
    prediccion <- predict(
        modelo,
        datamatrix,
        type = "leaf"
    )
    cat( "Fin prediccion\n" )

    for( arbolito in 1:qarbolitos )
    {
       cat( arbolito, " " )
       hojas_arbol <- unique(prediccion[ , arbolito])

       for (pos in 1:length(hojas_arbol)) {
         # el numero de nodo de la hoja, estan salteados
         nodo_id <- hojas_arbol[pos]
         dataset[ foto_mes== periodo, paste0(
            "rf_", sprintf("%03d", arbolito),
             "_", sprintf("%03d", nodo_id)
          ) :=  as.integer( nodo_id == prediccion[ , arbolito]) ]

       }

       rm( hojas_arbol )
    }
    cat( "\n" )

    rm( prediccion )
    rm( datamatrix )
    gc(verbose= FALSE)
  }

  gc(verbose= FALSE)

  # borro clase01 , no debe ensuciar el dataset
  dataset[ , clase01 := NULL ]

}

# %%
# Parametros de Feature Engineering  a partir de hojas de Random Forest

# Estos CUATRO parametros son los que se deben modificar
PARAM$FE_rf$arbolitos= 10
PARAM$FE_rf$hojas_por_arbol= 45
PARAM$FE_rf$datos_por_hoja= 150
PARAM$FE_rf$mtry_ratio= 0.1

###  num_iterations: 50-60         ### arbolitos = 10
###  num_leaves: 40-50             ### hojas_por_arbol = 8
###  num_data_in_leaf: 100-200     ### datos_por_hoja = 150
###  feature_fraction_bynode: 0.1  ### mtry_ratio = 0.2


# Estos son quasi fijos
PARAM$FE_rf$train$clase01_valor1 <- c( "BAJA+2", "BAJA+1")
PARAM$FE_rf$train$training <- c( 202101, 202102, 202103)

# Estos TAMBIEN son quasi fijos
PARAM$FE_rf$lgb_param <-list(
    # parametros que se pueden cambiar
    num_iterations = PARAM$FE_rf$arbolitos,
    num_leaves  = PARAM$FE_rf$hojas_por_arbol,
    min_data_in_leaf = PARAM$FE_rf$datos_por_hoja,
    feature_fraction_bynode  = PARAM$FE_rf$mtry_ratio,

    # para que LightGBM emule Random Forest
    boosting = "rf",
    bagging_fraction = ( 1.0 - 1.0/exp(1.0) ),
    bagging_freq = 1.0,
    feature_fraction = 1.0,

    # genericos de LightGBM
    max_bin = 31L,
    objective = "binary",
    first_metric_only = TRUE,
    boost_from_average = TRUE,
    feature_pre_filter = FALSE,
    force_row_wise = TRUE,
    verbosity = -100,
    max_depth = -1L,
    min_gain_to_split = 0.0,
    min_sum_hessian_in_leaf = 0.001,
    lambda_l1 = 0.0,
    lambda_l2 = 0.0,

    pos_bagging_fraction = 1.0,
    neg_bagging_fraction = 1.0,
    is_unbalance = FALSE,
    scale_pos_weight = 1.0,

    drop_rate = 0.1,
    max_drop = 50,
    skip_drop = 0.5,

    extra_trees = FALSE
  )

# %%
# Feature Engineering agregando variables de Random Forest
AgregaVarRandomForest()
# Out:
# inicio AgregaVarRandomForest()
# Error in lgb.Dataset(data = data.matrix(dataset[entrenamiento == TRUE, : could not find function "lgb.Dataset"
# Traceback:
#
# 1. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "could not find function \"lgb.Dataset\"", base::quote(lgb.Dataset(data = data.matrix(dataset[entrenamiento ==
#  .     TRUE, campos_buenos, with = FALSE]), label = dataset[entrenamiento ==
#  .     TRUE, clase01], free_raw_data = FALSE)))

# %%
dim(dataset)
colnames(dataset)
# Out:
# [1] 273666     56
#  [1] "numero_de_cliente"                "foto_mes"
#  [3] "internet"                         "cliente_edad"
#  [5] "cliente_antiguedad"               "mrentabilidad"
#  [7] "mrentabilidad_annual"             "mcomisiones"
#  [9] "mactivos_margen"                  "mpasivos_margen"
# [11] "cproductos"                       "mcuenta_corriente"
# [13] "mcaja_ahorro"                     "cdescubierto_preacordado"
# [15] "mcuentas_saldo"                   "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"            "mtarjeta_master_consumo"
# [19] "mprestamos_personales"            "cpayroll_trx"
# [21] "mpayroll"                         "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"        "chomebanking_transacciones"
# [25] "ctrx_quarter"                     "Master_status"
# [27] "Master_fechaalta"                 "Master_mpagominimo"
# [29] "Visa_status"                      "Visa_fechaalta"
# [31] "Visa_mpagominimo"                 "clase_ternaria"
# [33] "kmes"                             "mpayroll_sobre_edad"
# [35] "ratio_saldo_ingreso"              "promedio_diario_consumos"
# [37] "dias_consumo_alto"                "ratio_comisiones_consumos"
# [39] "ingreso_ajustado_antiguedad"      "saldo_cercano_cero"
# [41] "porc_consumo_digital"             "total_movimientos"
# [43] "ratio_productos_consumos"         "promedio_comisiones"
# [45] "saldo_alto"                       "dias_sin_transacciones"
# [47] "ingreso_mensual_promedio"         "promedio_diario_comisiones"
# [49] "proporcion_consumos_ingresos"     "ratio_comisiones_saldo"
# [51] "proporcion_transacciones_tarjeta" "productos_por_antiguedad"
# [53] "promedio_diario_consumos_total"   "gastos_semanales"
# [55] "clase01"                          "entrenamiento"

# %%
# No se implementa Feature Engineering a partir de Random Forest para gentencial, lo anterior fue agregado al código original.

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
# dataset[,
#    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
#    by = numero_de_cliente,
#    .SDcols = cols_lagueables
#]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
#    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %%
dim(dataset)
# Out:
# [1] 273666    162

# %% [markdown]
# Verificacion de los campos recien creados

# %%
#ncol(dataset)
#colnames(dataset)

# %%
# Creación de Nuevas Variables sin incluir variables del RF

dataset <- as.data.table(dataset)

################################################################################
### FEATURE 1: RATIOS & RENTABILIDAD (ratio_profitability_score)
###
### Resume el estado económico del cliente basado en:
### - rentabilidad anual
### - variaciones de rentabilidad (delta1, delta2, lag2)
### - ingresos relativos (mpayroll_sobre_edad)
### - margen de activos y pasivos
###
### Un valor ALTO = cliente sano
### Un valor BAJO = podría estar entrando en estrés financiero
################################################################################

dataset[, ratio_profitability_score :=
          scale(mrentabilidad_annual) +
          scale(mrentabilidad_annual_delta1) +
          #scale(mrentabilidad_annual_delta2) +
          #scale(mrentabilidad_annual_lag2) +
          scale(mpayroll_sobre_edad)      +
          #scale(mactivos_margen_delta2) +
          scale(mpasivos_margen)
        ]


################################################################################
### FEATURE 2: SALDOS & VARIACIONES (balance_trend_score)
###
### Captura movimientos estructurales del cliente:
### - saldo de cuentas (nivel)
### - variaciones de saldo (delta1, delta2)
### - préstamos personales y sus variaciones
### - límite de tarjetas (proxy de nivel económico)
###
### Valores ALTOS → crecimiento saludable
### Valores BAJOS → señales de retiro de dinero o reducción de crédito
################################################################################

dataset[, balance_trend_score :=
          scale(mcuentas_saldo) +
          scale(mcuentas_saldo_delta1) +
          #scale(mcuentas_saldo_delta2) +
          scale(mprestamos_personales)   #  +
          #scale(mprestamos_personales_delta2) +
          #scale(Master_mfinanciacion_limite)
        ]


################################################################################
### FEATURE 3: ACTIVIDAD & USO OPERATIVO (activity_behavior_score)
###
### Resume cómo usa el banco:
### - transacciones recientes (ctrx_quarter)
### - uso de Visa (Visa_msaldototal)
### - comisiones (lag1, lag2)
### - operaciones de homebanking
###
### Valores altos → cliente activo
### Valores bajos → cliente desconectándose
################################################################################

dataset[, activity_behavior_score :=
          scale(ctrx_quarter) +
          #scale(Visa_msaldototal) +
          scale(mcomisiones_lag1)    #   +
          #scale(mcomisiones_lag2) +
          #scale(chomebanking_transacciones_delta2)
        ]

# %%
dim(dataset)
class(dataset)
# Out:
# [1] 273666    165
# [1] "data.table" "data.frame"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 202005, 202107 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 202005, 202106 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202107)

PARAM$trainingstrategy$training <- c(
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 0.5


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# ========================================
# Campos clave en datos de entrenamiento:
# ========================================

# Seleccione UNO de los siguientes experimentos descomentando la línea correspondiente:
# (Asegúrese de que solo UNA línea esté descomentada)

# Experimento 1: Modelo Base - Incluye todas las variables
#  PARAM$excluir_campos <- c()  # <- ACTIVO POR DEFECTO

# Experimento 2: Exclusión de numero_de_cliente
# PARAM$excluir_campos <- c("numero_de_cliente")

# Experimento 3: Exclusión de foto_mes
# PARAM$excluir_campos <- c("foto_mes")

# Experimento 4: Exclusión de ambas variables
 PARAM$excluir_campos <- c("numero_de_cliente", "foto_mes")

# Imprimir configuración activa
cat("\n========== CONFIGURACIÓN ACTIVA ==========\n")
if (length(PARAM$excluir_campos) == 0) {
    cat("Experimento 1: Modelo Base (todas las variables incluidas)\n")
} else if (identical(PARAM$excluir_campos, c("numero_de_cliente"))) {
    cat("Experimento 2: Exclusión de numero_de_cliente\n")
} else if (identical(PARAM$excluir_campos, c("foto_mes"))) {
    cat("Experimento 3: Exclusión de foto_mes\n")
} else if (setequal(PARAM$excluir_campos, c("numero_de_cliente", "foto_mes"))) {
    cat("Experimento 4: Exclusión de numero_de_cliente y foto_mes\n")
}
cat("Campos a excluir:", ifelse(length(PARAM$excluir_campos) == 0, "Ninguno", paste(PARAM$excluir_campos, collapse=", ")), "\n")
cat("==========================================\n\n")

# ========================================
# Campos clave en datos de entrenamiento:
# ========================================
# Out:
# ========== CONFIGURACIÓN ACTIVA ==========
# Experimento 4: Exclusión de numero_de_cliente y foto_mes
# Campos a excluir: numero_de_cliente, foto_mes
# ==========================================

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# ========================================
# Campos clave en datos de entrenamiento:
# ========================================

 if (exists("PARAM") && !is.null(PARAM$excluir_campos) && length(PARAM$excluir_campos) > 0) {
    cat("Excluyendo campos del entrenamiento:", paste(PARAM$excluir_campos, collapse=", "), "\n")
    campos_buenos <- setdiff(campos_buenos, PARAM$excluir_campos)
    cat("Total de campos después de exclusión:", length(campos_buenos), "\n\n")
} else {
    cat("No se excluyen campos adicionales del entrenamiento\n")
    cat("Total de campos:", length(campos_buenos), "\n\n")
}

# ========================================
# Campos clave en datos de entrenamiento:
# ========================================
# Out:
# Excluyendo campos del entrenamiento: numero_de_cliente, foto_mes
# Total de campos después de exclusión: 161

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16551

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 20

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31,

  num_iterations= 9999,  # valor grande, lo limita early_stopping_rounds
  early_stopping_rounds= 1000
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_leaves", lower= 164L, upper= 416L),
  makeIntegerParam("min_data_in_leaf", lower= 2L, upper= 5000L),
  makeNumericParam("feature_fraction", lower= 0.1, upper= 0.9),
  makeNumericParam("learning_rate", lower= 0.005, upper= 0.4)
)

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Sun Nov 30 07:45:53 PM 2025 AUC 0.999992817074047
#
# Sun Nov 30 07:46:43 PM 2025 AUC 0.999988878050137
#
# Sun Nov 30 07:47:32 PM 2025 AUC 0.99998424390436
#
# Sun Nov 30 07:48:39 PM 2025 AUC 0.99999606097609
#
# Sun Nov 30 07:49:37 PM 2025 AUC 0.999991195123025
#
# Sun Nov 30 07:50:26 PM 2025 AUC 0.999980768295028
#
# Sun Nov 30 07:51:07 PM 2025 AUC 0.999996292683379
#
# Sun Nov 30 07:53:38 PM 2025 AUC 0.999995829268801
#
# Sun Nov 30 07:54:27 PM 2025 AUC 0.999996524390668
#
# Sun Nov 30 07:55:30 PM 2025 AUC 0.999994439025068
#
# Sun Nov 30 07:56:09 PM 2025 AUC 0.999997219512534
#
# Sun Nov 30 07:57:01 PM 2025 AUC 0.999996524390668
#
# Sun Nov 30 07:59:00 PM 2025 AUC 0.999646878091844
#
# Sun Nov 30 07:59:37 PM 2025 AUC 0.999994670732357
#
# Sun Nov 30 08:00:47 PM 2025 AUC 0.999995829268801
#
# Sun Nov 30 08:01:20 PM 2025 AUC 0.999998609756267
#
# [mbo] 0: num_leaves=295; min_data_in_leaf=1495; feature_fraction=0.367; learning_rate=0.226 : y = 1 : 53.9 secs : initdesign
#
# [mbo] 0: num_leaves=270; min_data_in_leaf=2831; feature_fraction=0.248; learning_rate=0.321 : y = 1 : 49.4 secs : initdesign
#
# [mbo] 0: num_leaves=204; min_data_in_leaf=1121; feature_fraction=0.296; learning_rate=0.273 : y = 1 : 49.0 secs : initdesign
#
# [mbo] 0: num_leaves=241; min_data_in_leaf=3873; feature_fraction=0.655; learning_rate=0.0432 : y = 1 : 67.3 secs : initdesign
#
# [mbo] 0: num_leaves=332; min_data_in_leaf=2060; feature_fraction=0.524; learning_rate=0.233 : y = 1 : 57.9 secs : initdesign
#
# [mbo] 0: num_leaves=245; min_data_in_leaf=2300; feature_fraction=0.154; learning_rate=0.186 : y = 1 : 49.2 secs : initdesign
#
# [mbo] 0: num_leaves=368; min_data_in_leaf=4587; feature_fraction=0.776; learning_rate=0.167 : y = 1 : 40.8 secs : initdesign
#
# [mbo] 0: num_leaves=394; min_data_in_leaf=3743; feature_fraction=0.618; learning_rate=0.00976 : y = 1 : 150.9 secs : initdesign
#
# [mbo] 0: num_leaves=383; min_data_in_leaf=4295; feature_fraction=0.343; learning_rate=0.299 : y = 1 : 49.4 secs : initdesign
#
# [mbo] 0: num_leaves=164; min_data_in_leaf=1655; feature_fraction=0.59; learning_rate=0.074 : y = 1 : 62.7 secs : initdesign
#
# [mbo] 0: num_leaves=340; min_data_in_leaf=867; feature_fraction=0.709; learning_rate=0.124 : y = 1 : 39.1 secs : initdesign
#
# [mbo] 0: num_leaves=192; min_data_in_leaf=2514; feature_fraction=0.477; learning_rate=0.369 : y = 1 : 51.6 secs : initdesign
#
# [mbo] 0: num_leaves=312; min_data_in_leaf=47; feature_fraction=0.103; learning_rate=0.152 : y = 1 : 119.8 secs : initdesign
#
# [mbo] 0: num_leaves=414; min_data_in_leaf=3316; feature_fraction=0.821; learning_rate=0.392 : y = 1 : 36.3 secs : initdesign
#
# [mbo] 0: num_leaves=278; min_data_in_leaf=4694; feature_fraction=0.444; learning_rate=0.0832 : y = 1 : 70.5 secs : initdesign
#
# [mbo] 0: num_leaves=213; min_data_in_leaf=385; feature_fraction=0.851; learning_rate=0.336 : y = 1 : 33.2 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Sun Nov 30 08:01:58 PM 2025 AUC 0.999995829268801
#
# [mbo] 1: num_leaves=206; min_data_in_leaf=1122; feature_fraction=0.849; learning_rate=0.397 : y = 1 : 36.9 secs : infill_ei
#
# Sun Nov 30 08:02:50 PM 2025 AUC 0.999993048781336
#
# [mbo] 2: num_leaves=164; min_data_in_leaf=1778; feature_fraction=0.336; learning_rate=0.379 : y = 1 : 50.9 secs : infill_ei
#
# Sun Nov 30 08:03:42 PM 2025 AUC 0.999993512195913
#
# [mbo] 3: num_leaves=164; min_data_in_leaf=1100; feature_fraction=0.586; learning_rate=0.294 : y = 1 : 52.3 secs : infill_ei
#
# Sun Nov 30 08:04:42 PM 2025 AUC 0.999990731708447
#
# [mbo] 4: num_leaves=194; min_data_in_leaf=2475; feature_fraction=0.352; learning_rate=0.144 : y = 1 : 59.7 secs : infill_ei
#
# Sun Nov 30 08:06:00 PM 2025 AUC 0.999996987805245
#
# [mbo] 5: num_leaves=207; min_data_in_leaf=809; feature_fraction=0.9; learning_rate=0.0268 : y = 1 : 77.7 secs : infill_ei
#
# Sun Nov 30 08:06:37 PM 2025 AUC 0.999998609756267
#
# [mbo] 6: num_leaves=416; min_data_in_leaf=733; feature_fraction=0.9; learning_rate=0.348 : y = 1 : 35.9 secs : infill_ei
#
# Sun Nov 30 08:07:32 PM 2025 AUC 0.999989804879292
#
# [mbo] 7: num_leaves=280; min_data_in_leaf=3643; feature_fraction=0.523; learning_rate=0.4 : y = 1 : 54.9 secs : infill_ei
#
# Sun Nov 30 08:08:12 PM 2025 AUC 0.99999606097609
#
# [mbo] 8: num_leaves=268; min_data_in_leaf=1270; feature_fraction=0.774; learning_rate=0.198 : y = 1 : 39.9 secs : infill_ei
#
# Sun Nov 30 08:09:48 PM 2025 AUC 0.999995829268801
#
# [mbo] 9: num_leaves=301; min_data_in_leaf=2830; feature_fraction=0.804; learning_rate=0.00528 : y = 1 : 95.4 secs : infill_ei
#
# Sun Nov 30 08:10:20 PM 2025 AUC 0.999997914634401
#
# [mbo] 10: num_leaves=228; min_data_in_leaf=660; feature_fraction=0.899; learning_rate=0.392 : y = 1 : 31.6 secs : infill_ei
#
# Sun Nov 30 08:11:30 PM 2025 AUC 0.999989341464714
#
# [mbo] 11: num_leaves=167; min_data_in_leaf=4601; feature_fraction=0.1; learning_rate=0.269 : y = 1 : 70.0 secs : infill_ei
#
# Saved the current state after iteration 12 in the file HT.RDATA.
#
# Sun Nov 30 08:18:03 PM 2025 AUC 0.999962926833789
#
# [mbo] 12: num_leaves=416; min_data_in_leaf=5000; feature_fraction=0.1; learning_rate=0.00721 : y = 1 : 392.1 secs : infill_ei
#
# Sun Nov 30 08:18:40 PM 2025 AUC 0.999995481707868
#
# [mbo] 13: num_leaves=164; min_data_in_leaf=4591; feature_fraction=0.623; learning_rate=0.399 : y = 1 : 37.5 secs : infill_ei
#
# Sun Nov 30 08:19:18 PM 2025 AUC 0.99999212195218
#
# [mbo] 14: num_leaves=416; min_data_in_leaf=2727; feature_fraction=0.676; learning_rate=0.308 : y = 1 : 36.7 secs : infill_ei
#
# Sun Nov 30 08:19:53 PM 2025 AUC 0.999994902439646
#
# [mbo] 15: num_leaves=164; min_data_in_leaf=3042; feature_fraction=0.9; learning_rate=0.313 : y = 1 : 35.4 secs : infill_ei
#
# Sun Nov 30 08:20:29 PM 2025 AUC 0.99999501829329
#
# [mbo] 16: num_leaves=298; min_data_in_leaf=4111; feature_fraction=0.9; learning_rate=0.316 : y = 1 : 35.5 secs : infill_ei
#
# Sun Nov 30 08:21:47 PM 2025 AUC 0.999997451219823
#
# [mbo] 17: num_leaves=416; min_data_in_leaf=1107; feature_fraction=0.829; learning_rate=0.00582 : y = 1 : 77.5 secs : infill_ei
#
# Saved the current state after iteration 18 in the file HT.RDATA.
#
# Sun Nov 30 08:22:43 PM 2025 AUC 0.999993743903202
#
# [mbo] 18: num_leaves=416; min_data_in_leaf=4999; feature_fraction=0.515; learning_rate=0.37 : y = 1 : 56.1 secs : infill_ei
#
# Sun Nov 30 08:23:33 PM 2025 AUC 0.999992353659469
#
# [mbo] 19: num_leaves=227; min_data_in_leaf=5000; feature_fraction=0.286; learning_rate=0.4 : y = 1 : 49.0 secs : infill_ei
#
# Sun Nov 30 08:24:22 PM 2025 AUC 0.999995829268801
#
# [mbo] 20: num_leaves=337; min_data_in_leaf=4339; feature_fraction=0.599; learning_rate=0.256 : y = 1 : 48.9 secs : infill_ei
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_data_in_leaf feature_fraction learning_rate num_iterations
#         <int>            <int>            <num>         <num>          <int>
# 1:        213              385        0.8509975     0.3358682              3

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 15705300
#
# $envios
# [1] 391

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_2108704764
#                     2

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "labo-i-2025-virtual-gerencial"
PARAM$kaggle$cortes <- seq(800, 1300, by = 50)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Warning message in 1:envios:
# “numerical expression has 16551 elements: only the first used”
# Successfully submitted to LaboI 2025 Virtual gerencial
# Warning message in 1:envios:
# “numerical expression has 16551 elements: only the first used”
# Successfully submitted to LaboI 2025 Virtual gerencial
# Warning message in 1:envios:
# “numerical expression has 16551 elements: only the first used”
# Successfully submitted to LaboI 2025 Virtual gerencial
# Warning message in 1:envios:
# “numerical expression has 16551 elements: only the first used”
# Successfully submitted to LaboI 2025 Virtual gerencial
# Warning message in 1:envios:
# “numerical expression has 16551 elements: only the first used”
# Successfully submitted to LaboI 2025 Virtual gerencial
# Warning message in 1:envios:
# “numerical expression has 16551 elements: only the first used”
# Successfully submitted to LaboI 2025 Virtual gerencial
# Warning message in 1:envios:
# “numerical expression has 16551 elements: only the first used”
# Successfully submitted to LaboI 2025 Virtual gerencial
# Warning message in 1:envios:
# “numerical expression has 16551 elements: only the first used”
# Successfully submitted to LaboI 2025 Virtual gerencial
# Warning message in 1:envios:
# “numerical expression has 16551 elements: only the first used”
# Successfully submitted to LaboI 2025 Virtual gerencial
# Warning message in 1:envios:
# “numerical expression has 16551 elements: only the first used”
# Successfully submitted to LaboI 2025 Virtual gerencial
# Warning message in 1:envios:
# “numerical expression has 16551 elements: only the first used”
# Successfully submitted to LaboI 2025 Virtual gerencial

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Nov 30 08:27:17 PM 2025"
